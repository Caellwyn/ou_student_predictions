# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, RandomTreesEmbedding, \
ExtraTreesClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import plot_confusion_matrix, accuracy_score, f1_score
from sklearn.exceptions import ConvergenceWarning

from xgboost import XGBClassifier, XGBRFClassifier, plot_importance
import matplotlib.pyplot as plt
import warnings

import pickle

import os
import sys
module_path = os.path.abspath(os.path.join(os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)
from src.functions import add_model, test_model, get_timeseries_table

from seaborn import heatmap

warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %%
def model_each_feature(model, verbose=1, save=True,
                   vectorization=None,
                   regularization=None,
                   regularization_strength=None,
                   class_imbalance=None):
    """Takes an unfitted model and optional entries for hyperparameter table and returns 
    the fitted model.
    fits model on each of X_t_clicks, X_t_activities, X_t_product, and all 3 features in X_t.
    Loads hyperparameter table from disk, writes entries for each of the 4 datasets.
    if save=False, will not save over hyperparameter table file on disk.
    if verbose=1, display the hyperparamter table.  
    If verbose = 2+, also display model.score_ and confusion matrix"""
    try:
        h_table = pd.read_csv('hyper_parameter_table_withdrawals.csv')
    except:
        h_table = None

    model.fit(X_t, y_t)

    h_table = add_model(model, X_t, y_t, X_val, y_val, 
                            features = 'all, and predicting withdrawals',
                            table=h_table, 
                            class_imbalance=class_imbalance)

    if verbose > 1:
        print(feature)
        test_model(model, X_val, y_val, plot_confusion=True)
            
    if save:
        h_table.to_csv('hyper_parameter_table_withdrawals.csv', index=False)
    if verbose > 0:
        display(h_table)
    return model

# %%
prediction_window = 135

df = get_timeseries_table(prediction_window=prediction_window,
                         binary_labels=False, one_hot_modules=True)

binary_map = {'Fail':0,
             'Withdrawn':1,
             'Pass':0,
             'Distinction':0}

df['final_result']= df['final_result'].map(binary_map)


X = df.drop(columns=['final_result'])
y = df['final_result']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=111)
X_t, X_val, y_t, y_val = train_test_split(X_train, y_train, random_state=111)

# X_train_clicks = X_train.loc[:,X_train.columns.str.startswith('sum_click')]
# X_test_clicks = X_test.loc[:,X_test.columns.str.startswith('sum_click')]
# X_t_clicks = X_t.loc[:,X_t.columns.str.startswith('sum_click')]
# X_val_clicks = X_val.loc[:,X_val.columns.str.startswith('sum_click')]

# X_train_activities = X_train.loc[:,X_train.columns.str.startswith('sum_activities')]
# X_test_activities = X_test.loc[:,X_test.columns.str.startswith('sum_activities')]
# X_t_activities = X_t.loc[:,X_t.columns.str.startswith('sum_activities')]
# X_val_activities = X_val.loc[:,X_val.columns.str.startswith('sum_activities')]

# X_train_product = X_train.loc[:,X_train.columns.str.startswith('activities_x_clicks')]
# X_test_product = X_test.loc[:,X_test.columns.str.startswith('activities_x_clicks')]
# X_t_product = X_t.loc[:,X_t.columns.str.startswith('activities_x_clicks')]
# X_val_product = X_val.loc[:,X_val.columns.str.startswith('activities_x_clicks')]

y_t
# Out:
# registration
# FFF2013B481453     0
# CCC2014B57340      0
# GGG2014J679840     0
# DDD2013J570403     0
# BBB2013J606377     0
#                   ..
# FFF2014J398630     0
# CCC2014J2598631    0
# DDD2014J646344     0
# GGG2014J654062     0
# BBB2013J576946     0
# Name: final_result, Length: 13502, dtype: int64

# %%
y_t.value_counts()
# Out:
# 0    12423
# 1     1079
# Name: final_result, dtype: int64

# %% [markdown]
# h_table = None

# %%
model = LogisticRegression(random_state=111)
model_each_feature(model, verbose=0)
# Out:
# LogisticRegression(random_state=111)

# %%
class_imbalance = 'balanced weights'
model = LogisticRegression(class_weight='balanced', random_state=111)
model_each_feature(model, class_imbalance=class_imbalance, verbose=0)
# Out:
# LogisticRegression(class_weight='balanced', random_state=111)

# %%
model = DecisionTreeClassifier(random_state=111)
model_each_feature(model, verbose=0)
# Out:
# DecisionTreeClassifier(random_state=111)

# %%
model = DecisionTreeClassifier(class_weight='balanced', random_state=111)
model_each_feature(model, verbose=0, class_imbalance=class_imbalance)
# Out:
# DecisionTreeClassifier(class_weight='balanced', random_state=111)

# %%
model = RandomForestClassifier(random_state=111)
model_each_feature(model, verbose=0)
# Out:
# RandomForestClassifier(random_state=111)

# %%
model = RandomForestClassifier(class_weight='balanced', random_state=111)
model_each_feature(model, verbose=0, class_imbalance=class_imbalance)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=111)

# %%
model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=111)
model_each_feature(model, verbose=0)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='logloss',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, random_state=111, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=1, subsample=1, tree_method='exact',
#               use_label_encoder=False, validate_parameters=1, verbosity=None)

# %%
pd.read_csv('hyper_parameter_table.csv')
# Out:
#                      model vectorization  \
# 0            XGBClassifier          None
# 1   RandomForestClassifier          None
# 2   RandomForestClassifier          None
# 3   RandomForestClassifier          None
# 4   RandomForestClassifier          None
# 5   RandomForestClassifier          None
# 6   RandomForestClassifier          None
# 7   RandomForestClassifier          None
# 8   RandomForestClassifier          None
# 9            XGBClassifier          None
# 10      LogisticRegression          None
# 11           XGBClassifier          None
# 12           XGBClassifier          None
# 13      LogisticRegression          None
# 14      LogisticRegression          None
# 15      LogisticRegression          None
# 16      LogisticRegression          None
# 17  DecisionTreeClassifier          None
# 18  DecisionTreeClassifier          None
# 19      LogisticRegression          None
# 20  DecisionTreeClassifier          None
# 21  DecisionTreeClassifier          None
# 22  DecisionTreeClassifier          None
# 23  DecisionTreeClassifier          None
# 24  DecisionTreeClassifier          None
# 25  DecisionTreeClassifier          None
# 26      LogisticRegression          None
# 27      LogisticRegression          None
#
#                                         features regularization  \
# 0   clicks_activities_product_assessments_module           None
# 1   clicks_activities_product_assessments_module           None
# 2   clicks_activities_product_assessments_module           None
# 3                                         clicks           None
# 4                                     activities           None
# 5                            activities_x_clicks           None
# 6                                         clicks           None
# 7                                     activities           None
# 8                            activities_x_clicks           None
# 9                            activities_x_clicks           None
# 10  clicks_activities_product_assessments_module             l2
# 11                                        clicks           None
# 12                                    activities           None
# 13                                    activities             l2
# 14                                        clicks             l2
# 15  clicks_activities_product_assessments_module             l2
# 16                           activities_x_clicks             l2
# 17  clicks_activities_product_assessments_module           None
# 18  clicks_activities_product_assessments_module           None
# 19                           activities_x_clicks             l2
# 20                           activities_x_clicks           None
# 21                                    activities           None
# 22                                        clicks           None
# 23                                        clicks           None
# 24                                    activities           None
# 25                           activities_x_clicks           None
# 26                                    activities             l2
# 27                                        clicks             l2
#
#    regularization_strength   class_imbalance  train_accuracy  val_accuracy  \
# 0                     None              None        0.972078      0.841369
# 1                     None              None        1.000000      0.828260
# 2                     None  balanced weights        1.000000      0.817374
# 3                     None              None        0.999926      0.794046
# 4                     None              None        0.999926      0.793379
# 5                     None              None        0.999926      0.792046
# 6                     None  balanced weights        0.999926      0.788936
# 7                     None  balanced weights        0.999926      0.786936
# 8                     None  balanced weights        0.999926      0.784270
# 9                     None              None        0.955192      0.788714
# 10                     1.0              None        0.788846      0.774939
# 11                    None              None        0.951192      0.785159
# 12                    None              None        0.943564      0.783159
# 13                     1.0              None        0.781884      0.775383
# 14                     1.0              None        0.768479      0.765163
# 15                     1.0  balanced weights        0.772700      0.763830
# 16                     1.0              None        0.739816      0.731393
# 17                    None  balanced weights        1.000000      0.764497
# 18                    None              None        1.000000      0.760498
# 19                     1.0  balanced weights        0.737002      0.730949
# 20                    None  balanced weights        0.999926      0.702066
# 21                    None  balanced weights        0.999926      0.695401
# 22                    None  balanced weights        0.999926      0.691846
# 23                    None              None        0.999926      0.694068
# 24                    None              None        0.999926      0.684070
# 25                    None              None        0.999926      0.676961
# 26                     1.0  balanced weights        0.703377      0.706065
# 27                     1.0  balanced weights        0.676270      0.688514
#
#     train_f1_score  val_f1_score
# 0         0.978431      0.881079
# 1         1.000000      0.877360
# 2         1.000000      0.869524
# 3         0.999942      0.855495
# 4         0.999942      0.855320
# 5         0.999942      0.854568
# 6         0.999942      0.851702
# 7         0.999942      0.850693
# 8         0.999942      0.848872
# 9         0.964921      0.843250
# 10        0.852104      0.841347
# 11        0.961799      0.840561
# 12        0.955989      0.838784
# 13        0.833192      0.828207
# 14        0.823110      0.820024
# 15        0.826089      0.817886
# 16        0.821358      0.815898
# 17        1.000000      0.815780
# 18        1.000000      0.810345
# 19        0.796119      0.790521
# 20        0.999942      0.767551
# 21        0.999942      0.760357
# 22        0.999942      0.758573
# 23        0.999942      0.758209
# 24        0.999942      0.748319
# 25        0.999942      0.742837
# 26        0.736911      0.740028
# 27        0.701373      0.714111

# %%
model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
model.fit(X_t, y_t)
plot_confusion_matrix(model, X_val, y_val, normalize='true', cmap='Greens')

# %%
importance = pd.DataFrame(model.feature_importances_, index=X_t.columns)
importance.sort_values(by=0, ascending=False).head(20)
# Out:
#                                 0
# module_GGG               0.015664
# sum_activities_132       0.009348
# sum_click_128            0.007045
# sum_activities_131       0.007015
# module_DDD               0.006759
# assess_score_7           0.006071
# activities_x_clicks_97   0.005652
# sum_click_105            0.005441
# sum_click_72             0.005419
# sum_activities_133       0.005407
# activities_x_clicks_123  0.005076
# assess_score_3           0.004888
# activities_x_clicks_134  0.004877
# sum_click_115            0.004625
# assess_score_4           0.004105
# sum_activities_57        0.004074
# sum_click_110            0.004074
# activities_x_clicks_-12  0.004057
# activities_x_clicks_121  0.004037
# module_CCC               0.004033

# %%
model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
model.fit(X_train, y_train)
model.score(X_test, y_test)
plot_confusion_matrix(model, X_test, y_test, cmap='Greens')
